# %%
import mitsuba as mi

# %%
import mitsuba as mi
mi.set_variant("cuda_ad_rgb")
img = mi.render(mi.load_dict(mi.cornell_box()), spp=10240)
mi.Bitmap(img).write("cbox.exr")

# %%
scene = mi.load_dict(mi.cornell_box())
original_image = mi.render(scene, spp=1024)

import matplotlib.pyplot as plt
plt.axis('off')
plt.imshow(original_image ** (1.0 / 2.2));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..3.7801154].

# %%
import importlib
import lens.lens_module
importlib.reload(lens.lens_module)
# Out:
# <module 'lens.lens_module' from '/mnt/ssd2/pengfei/workspace/USTC_CG_24/Framework3D/python/lens/lens_module.py'>
